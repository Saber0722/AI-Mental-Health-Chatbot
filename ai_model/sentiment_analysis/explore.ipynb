# %%
# imports
from datasets import load_dataset
import pandas as pd

# %%
# dataset
df = load_dataset("go_emotions")
print(df)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 43410
#     })
#     validation: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5426
#     })
#     test: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5427
#     })
# })

# %%
# Out:
# Dataset({
#     features: ['text', 'labels', 'id'],
#     num_rows: 43410
# })

# %%
# Saving 1000 samples to CSV for verification
data_train = df['train'][:1000]
data_train = pd.DataFrame(data_train)
data_train.to_csv('../data/go_emotions_sample.csv', index=False)
